# %%
import pandas as pd
import numpy as np

# %%
stores = pd.read_csv('stores.csv', sep=',',header='infer')

# %%
feature = pd.read_csv('features.csv', sep=',',header='infer')
feature = pd.merge(feature, stores, on=['Store'])
feature
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# 5         1  2010-03-12        57.79       2.667        NaN        NaN
# 6         1  2010-03-19        54.58       2.720        NaN        NaN
# 7         1  2010-03-26        51.45       2.732        NaN        NaN
# 8         1  2010-04-02        62.27       2.719        NaN        NaN
# 9         1  2010-04-09        65.86       2.770        NaN        NaN
# 10        1  2010-04-16        66.32       2.808        NaN        NaN
# 11        1  2010-04-23        64.84       2.795        NaN        NaN
# ...

# %%
train = pd.read_csv('train.csv', sep=',',header='infer')
train = pd.merge(train, feature, on=['Store','Date', 'IsHoliday'])
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     2  2010-02-05      50605.27      False        42.31
# 2           1     3  2010-02-05      13740.12      False        42.31
# 3           1     4  2010-02-05      39954.04      False        42.31
# 4           1     5  2010-02-05      32229.38      False        42.31
# 5           1     6  2010-02-05       5749.03      False        42.31
# 6           1     7  2010-02-05      21084.08      False        42.31
# 7           1     8  2010-02-05      40129.01      False        42.31
# 8           1     9  2010-02-05      16930.99      False        42.31
# 9           1    10  2010-02-05      30721.50      False        42.31
# 10          1    11  2010-02-05      24213.18      False        42.31
# 11          1    12  2010-02-05       8449.54      False        42.31
# ...

# %%
train.to_csv("train_merged.csv", sep=',', na_rep='NA', index=False)

# %%
submit = pd.read_csv('sampleSubmission.csv', sep='_',header='infer')
submit = pd.merge(submit, feature, on=['Store','Date'])
submit
# submit.to_csv('submit_merged.csv', sep=',', na_rep='NA', index=False)
# Out:
#         Store  Dept        Date  Temperature  Fuel_Price  MarkDown1  \
# 0           1     1  2012-11-02        55.32       3.386    6766.44
# 1           1     2  2012-11-02        55.32       3.386    6766.44
# 2           1     3  2012-11-02        55.32       3.386    6766.44
# 3           1     4  2012-11-02        55.32       3.386    6766.44
# 4           1     5  2012-11-02        55.32       3.386    6766.44
# 5           1     6  2012-11-02        55.32       3.386    6766.44
# 6           1     7  2012-11-02        55.32       3.386    6766.44
# 7           1     8  2012-11-02        55.32       3.386    6766.44
# 8           1     9  2012-11-02        55.32       3.386    6766.44
# 9           1    10  2012-11-02        55.32       3.386    6766.44
# 10          1    11  2012-11-02        55.32       3.386    6766.44
# 11          1    12  2012-11-02        55.32       3.386    6766.44
# 12          1    13  2012-11-02        55.32       3.386    6766.44
# ...
